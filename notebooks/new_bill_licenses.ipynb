# %%
import pandas as pd

licenses_df = pd.read_excel("../data/licenses.xlsx")
licenses_df.head()
licenses_df.columns
# Out:
# Index(['minutes_date', 'license_number', 'business_name', 'dba_name',
#        'address', 'street_number', 'street_name', 'city', 'state', 'zipcode',
#        'alcohol_type', 'manager', 'attorney', 'status', 'status_detail',
#        'details', 'entity_number', 'file_name'],
#       dtype='str')

# %%
# Tracker New Bill Licenses
applying_bus=["Crystal Spoons, LLC", "El Centro", "La Parada Dominican Kitchen", "Murl's Kitchen", "JustBook-ish", 
"Minina Cafe", "One Family Diner", "Fresh Food Generation", "Blue Mountain Jamaican Restaurant", "Angelas Cafe", 
"Cabana Grill", "Caffe Dello Sport Eastie", "Con Sabor A Colombia, Inc.", "Florenza", "Mi Pueblito Restaurant", 
"Peruvian Taste Restaurant", "BB.Q Chicken", "Don Tequeno y Dona Arepa", "Mangu Dominican Bistro", "Momo Masala", 
"Stoked Pizza", "Harry's All American", "Mi Finca Mexican Restaurant and Pizzeria", "Las Delicias Colombianas 2", "Little Haiti International Cuisine", "Huntington Theatre", 
"Jeffries Yacht Club", "Zoo New England", "SubRosa and Humaari", "El Barrio Mexican Grill", "Mesob Restaurant", "Mondo", 
"Wash El Beverages, LLC", "District 7 Cafe", "The Mix Vault", "The Weston Way, LLC", "Cool Shade Jamaican Restaurant, LLC", "Blasi Cafe", 
"Milkweed", "Pizza 24", "Doune & Pepe", "Molinaris", "Chilacates Cantina", "Mofongo Factory Restaurant", "El Jardin", 
"Los Alebrijes Restaurant", "Taqueria Jalisco", "The Smoke Shop BBQ", "La Tavernetta by Mida", "AAA Restaurant", "Jadu", 
"Miami Restaurant", "Mr Drinky", "The Green T Coffee Shop", "Knoll Street Tavern", "sweeties", "Somtum Modern Thai Cuisine", 
"Boston Pickle Club", "Capri", "Bono Restaurant and Catering", "American Repertory Theatre", "Boston Center for the Arts", 
"Sorrel and Lime, LLC", "The Substation", "From Scratch", "Mos Tavern & Kitchen", "AMA", 
"Gracenote Coffee Boston", "Merengue Express"]

# %%
import pandas as pd

# 1. Standardize the lookup set
applying_bus_set = set(name.strip().lower() for name in applying_bus)

# 2. Check for required columns
cols = licenses_df.columns
if "business_name" in cols and "dba_name" in cols:
    
    # 3. Create boolean masks for both columns
    # We strip and lower both for a fair comparison
    mask_bus = licenses_df["business_name"].str.strip().str.lower().isin(applying_bus_set)
    mask_dba = licenses_df["dba_name"].str.strip().str.lower().isin(applying_bus_set)
    
    # 4. Filter DF where either column matches (| is the OR operator)
    matched_df = licenses_df[mask_bus | mask_dba].copy()
    
    # 5. Calculate missed businesses
    # Collect all names found in either column of our results
    found_bus_names = set(matched_df["business_name"].str.strip().str.lower())
    found_dba_names = set(matched_df["dba_name"].str.strip().str.lower())
    all_found_names = found_bus_names.union(found_dba_names)
    
    missed_names = [name for name in applying_bus if name.strip().lower() not in all_found_names]
    
    # 6. Print Results
    print(f"Found {len(matched_df)} matching rows.")
    print(f"Unique businesses matched: {len(applying_bus) - len(missed_names)} out of {len(applying_bus)}")
    
    if missed_names:
        print(f"\nMissed Businesses ({len(missed_names)}):")
        for name in missed_names:
            print(f" - {name}")
            
    # Display the result
    #display(matched_df) # Use display() in notebooks for better formatting
    
else:
    missing = [c for c in ["business_name", "dba_name"] if c not in licenses_df.columns]
    print(f"Error: Missing columns in licenses_df: {missing}")
# Out:
# Found 98 matching rows.
# Unique businesses matched: 69 out of 69

# %%
pd.set_option("display.max_rows", None)
#pd.reset_option("display.max_rows")


matched_df['minutes_date'] = pd.to_datetime(matched_df['minutes_date'], errors='coerce')

matched_df = (
    matched_df
    .sort_values(by='minutes_date', ascending=False)
    .drop_duplicates(subset='license_number', keep='first')
)

matched_df = matched_df.sort_values(
    by=["business_name", "dba_name"],
    ascending=[True, True],
    key=lambda col: col.str.lower()
)

cols = ["business_name", "dba_name", "alcohol_type","license_number"]
existing_cols = [c for c in cols if c in matched_df.columns]

matched_df[existing_cols]
# Out:
#                                  business_name  \
# 278                       1010 Morrissey Corp.
# 297                       1010 Morrissey Corp.
# 279               490 Harrison Restaurant, LLC
# 567                     567 Washington St, LLC
# 351                        AAA Restaurant, LLC
# 1261                          Allston BBQ, LLC
# 460                        Amabaka Corporation
# 231   American Repertory Theatre Company, Inc.
# 542                      Angelas Cafe II, Inc.
# 404                                  ATCF, LLC
# 462     Blue Mountain Jamaican Restaurant, LLC
# 574     Blue Mountain Jamaican Restaurant, LLC
# 232           Boston Center for the Arts, Inc.
# 328                   Boston Pickle Club, Inc.
# 465                             CabanaLV, Inc.
# 451                        Cholo Brothers, LLC
# 252               Cilantro Latin Kitchen Corp.
# 253                         Coffee Coffee, LLC
# 545        Commonwealth Zoological Corporation
# 354                               Con Rua, LLC
# 577                 Con Sabor A Colombia, Inc.
# 355        Cool Shade Jamaican Restaurant, LLC
# 513                        Crystal Spoons, LLC
# 2270                         DLS Kitchen, Inc.
# 547                    Dominican Kitchen, Inc.
# 256                                  DQC, Inc.
# 548                     DTDA Enterprises, Inc.
# 646                        East Boston BBQ LLC
# 1032                       East Boston BBQ LLC
# 1758                       East Boston Bbq LLC
# 549             Eastie Caffe Dello Sport, Inc.
# 1511                          El Barrio Mx LLC
# 217                          El Barrio MX, LLC
# 466                                  F&H, INC.
# 1893                                 F&H, Inc.
# 304                                   FAS, LLC
# 608                             Florenza, Inc.
# 795                             Florenza, Inc.
# 468                  Fresh Food Generation LLC
# 1433                Fresh Food Generation, LLC
# 765                                 Gelas Corp
# 1942                                Gelas Corp
# 552                                Gelas Corp.
# 674                         Gent Catering, LLC
# 358                        Gourmet Kreyol, LLC
# 257            GR Restaurant and Catering Inc.
# 920            GR Restaurant and Catering Inc.
# 583           Huntington Theatre Company, Inc.
# 1896          Huntington Theatre Company, Inc.
# 220                              J.J. & R, LLC
# 687                                  Jadu, LLC
# 489                        Jeffries Yacht Club
# 1732                       Jeffries Yacht Club
# 469                               JP BBQ, Inc.
# 870                        JSM 636 Group, Inc.
# 749                           justBook-ish LLC
# 310                          KKR Holdings, LLC
# 118                 La Tavernetta by Mida, LLC
# 656              Lajara Restaurant Corporation
# 1159            Lajara Restaurant, Corporation
# 586    Little Haiti International Cuisine, LLC
# 631              Los Alebrijes Restaurant, LLC
# 517                  M&K Restaurant Group, LLC
# 495                Mi Finca Mexican Foods, LLC
# 373                          Minina Cafe, Inc.
# 455                          Minina Cafe, Inc.
# 272                              Mr Drinky LLC
# 496                        Murl's Kitchen, LLC
# 446                               Nawiya, Inc.
# 273                  O'Brien & Armstrong, Inc.
# 523                     One Family Diner, Inc.
# 535                      Pinales Kitchen, Inc.
# 1493                     Pinales Kitchen, Inc.
# 262                             Pizza 24, Inc.
# 432                               Ravello, LLC
# 498                       S & S Restaurant LLC
# 228                            Shunny Day, LLC
# 457                          Siraj Corporation
# 415                       Sorrel and Lime, LLC
# 562                       Stoked Pizza JP, LLC
# 349                              sweeties, LLC
# 694       Taqueria Jalisco Orient Heights, LLC
# 265            Tejeda Brothers Investment, LLC
# 264            Tejeda Brothers Investment, LLC
# 246                The Comfort Collective, LLC
# 362                        The Weston Way, LLC
# 619                         Walter Corporation
# 2225                        Walter Corporation
# 276                     Wash El Beverages, LLC
# 742                        Workhub Boston, LLC
#
#                                       dba_name             alcohol_type  \
# 278                                   Milkweed  all alcoholic beverages
# 297                                   Milkweed  all alcoholic beverages
# 279                                      Capri  all alcoholic beverages
# 567                        SubRosa and Humaari  all alcoholic beverages
# 351                             AAA Restaurant  all alcoholic beverages
# 1261                              BB.Q Chicken  all alcoholic beverages
# 460                                Momo Masala  all alcoholic beverages
# 231                 American Repertory Theatre  all alcoholic beverages
# 542                               Angelas Cafe  all alcoholic beverages
# 404                        Knoll Street Tavern  all alcoholic beverages
# 462          Blue Mountain Jamaican Restaurant  all alcoholic beverages
# 574          Blue Mountain Jamaican Restaurant  all alcoholic beverages
# 232                 Boston Center for the Arts  all alcoholic beverages
# 328                         Boston Pickle Club  all alcoholic beverages
# 465                               Cabana Grill  all alcoholic beverages
# 451                  Peruvian Taste Restaurant  all alcoholic beverages
# 252                           Merengue Express  all alcoholic beverages
# 253                    Gracenote Coffee Boston  all alcoholic beverages
# 545                            Zoo New England  all alcoholic beverages
# 354                       Mos Tavern & Kitchen  all alcoholic beverages
# 577                                        NaN  all alcoholic beverages
# 355            Cool Shade Jamaicaan Restaurant  all alcoholic beverages
# 513                                        NaN  all alcoholic beverages
# 2270                    Mangu Dominican Bistro  all alcoholic beverages
# 547                La Parada Dominican Kitchen  all alcoholic beverages
# 256                         Chilacates Cantina  all alcoholic beverages
# 548                   Don Tequeno y Dona Arepa  all alcoholic beverages
# 646                         The Smoke Shop BBQ  all alcoholic beverages
# 1032                        The Smoke Shop BBQ  all alcoholic beverages
# 1758                        The Smoke Shop BBQ  all alcoholic beverages
# 549                   Caffe Dello Sport Eastie  all alcoholic beverages
# 1511                   El Barrio Mexican Grill  all alcoholic beverages
# 217                    El Barrio Mexican Grill  all alcoholic beverages
# 466                     Mi Pueblito Restaurant  all alcoholic beverages
# 1893                    MI PUEBLITO RESTAURANT  all alcoholic beverages
# 304                           Mesob Restaurant  all alcoholic beverages
# 608                                   Florenza  all alcoholic beverages
# 795                                   Florenza  all alcoholic beverages
# 468                      Fresh Food Generation  all alcoholic beverages
# 1433                     Fresh Food Generation                      NaN
# 765                 Las Delicias Colombianas 2  all alcoholic beverages
# 1942                Las Delicias Colombianas 2  all alcoholic beverages
# 552                 Las Delicias Colombianas 2  all alcoholic beverages
# 674                               From Scratch  all alcoholic beverages
# 358                               Doune & Pepe  all alcoholic beverages
# 257               Bono Restaurant and Catering  all alcoholic beverages
# 920               Bono Restaurant and Catering  all alcoholic beverages
# 583                         Huntington Theatre  all alcoholic beverages
# 1896                        Huntington Theatre  all alcoholic beverages
# 220                              The Mix Vault  all alcoholic beverages
# 687                                       Jadu  all alcoholic beverages
# 489                                        NaN  all alcoholic beverages
# 1732                                       NaN  all alcoholic beverages
# 469                               BB.Q Chicken  all alcoholic beverages
# 870                               bb.q Chicken  all alcoholic beverages
# 749                               justBook-ish  all alcoholic beverages
# 310                            District 7 Cafe  all alcoholic beverages
# 118                      La Tavernetta by Mida  all alcoholic beverages
# 656                 Mofongo Factory Restaurant  all alcoholic beverages
# 1159                Mofongo Factory Restaurant  all alcoholic beverages
# 586         Little Haiti International Cuisine  all alcoholic beverages
# 631                   Los Alebrijes Restaurant  all alcoholic beverages
# 517                                 Blasi Cafe  all alcoholic beverages
# 495   Mi Finca Mexican Restaurant and Pizzeria  all alcoholic beverages
# 373                                Minina Cafe  all alcoholic beverages
# 455                                Minina Cafe  all alcoholic beverages
# 272                                  Mr Drinky  all alcoholic beverages
# 496                             Murl's Kitchen  all alcoholic beverages
# 446                 Somtum Modern Thai Cuisine  all alcoholic beverages
# 273                    The Green T Coffee Shop  all alcoholic beverages
# 523                           One Family Diner  all alcoholic beverages
# 535                     Mangu Dominican Bistro  all alcoholic beverages
# 1493                    Mangu Dominican Bistro  all alcoholic beverages
# 262                                   Pizza 24  all alcoholic beverages
# 432                                  Molinaris  all alcoholic beverages
# 498                       Harry's All American  all alcoholic beverages
# 228                                      mondo  all alcoholic beverages
# 457                                  El Centro  all alcoholic beverages
# 415                                        NaN  all alcoholic beverages
# 562                               Stoked Pizza  all alcoholic beverages
# 349                                   sweeties  all alcoholic beverages
# 694                           Taqueria Jalisco  all alcoholic beverages
# 265                           Miami Restaurant  all alcoholic beverages
# 264                           Miami Restaurant  all alcoholic beverages
# 246                                        AMA  all alcoholic beverages
# 362                                        NaN  all alcoholic beverages
# 619                                  El Jardin  all alcoholic beverages
# 2225                                 El Jardin  all alcoholic beverages
# 276                                        NaN  all alcoholic beverages
# 742                             The Substation  all alcoholic beverages
#
#      license_number
# 278       LB-596016
# 297       LB-595701
# 279       LB-595024
# 567       LB-577208
# 351       LB-592817
# 1261       LB-99639
# 460       LB-582324
# 231       LB-599561
# 542       LB-578145
# 404       LB-587892
# 462       LB-583841
# 574       LB-577122
# 232       LB-599554
# 328       LB-593664
# 465       LB-583877
# 451       LB-584097
# 252       LB-598021
# 253       LB-597998
# 545       LB-578146
# 354       LB-592801
# 577       LB-577182
# 355       LB-592810
# 513       LB-580947
# 2270      LB-144189
# 547       LB-578141
# 256       LB-598023
# 548       LB-578134
# 646       LB-476499
# 1032      LB-537664
# 1758      LB-462626
# 549       LB-578142
# 1511      LB-482871
# 217       LB-601427
# 466       LB-583866
# 1893       LB-99814
# 304       LB-595045
# 608       LB-574154
# 795       LB-554019
# 468       LB-583884
# 1433      LB-489905
# 765       LB-465577
# 1942      LB-456206
# 552       LB-578144
# 674       LB-567244
# 358       LB-592854
# 257       LB-598009
# 920       LB-543917
# 583       LB-577211
# 1896      LB-457991
# 220       LB-601428
# 687       LB-567232
# 489       LB-582291
# 1732      LB-460881
# 469       LB-583839
# 870        LB-99577
# 749       LB-559007
# 310       LB-595032
# 118       LB-607770
# 656       LB-570339
# 1159      LB-100455
# 586       LB-577222
# 631       LB-572966
# 517        LB-99755
# 495       LB-582370
# 373       LB-590954
# 455       LB-584080
# 272       LB-596653
# 496       LB-582381
# 446       LB-584372
# 273       LB-596679
# 523       LB-581512
# 535       LB-580946
# 1493      LB-483678
# 262       LB-597972
# 432       LB-587130
# 498       LB-582320
# 228       LB-601426
# 457       LB-584103
# 415       LB-588304
# 562       LB-578143
# 349       LB-593736
# 694       LB-567250
# 265       LB-598072
# 264        LB-99632
# 246       LB-599551
# 362       LB-592818
# 619       LB-574267
# 2225      LB-440974
# 276       LB-596687
# 742       LB-561966

# %%
# Tracking Upgrades
import pandas as pd

# 1. Your input list
UPGRADES = ["LB-99619", "LB-99779", "LB-99607", "LB-99709", "LB-99753"]

# 2. Filter the DataFrame
# We use .copy() to avoid SettingWithCopyWarnings later
matched_df = licenses_df[licenses_df['license_number'].isin(UPGRADES)].copy()

# 3. Data Cleaning: Convert 'minutes_date' to actual datetime objects
# errors='coerce' will turn unparseable dates into NaT (Not a Time) instead of crashing
matched_df['minutes_date'] = pd.to_datetime(matched_df['minutes_date'], errors='coerce')

# 4. Sort and Deduplicate
# - Sort by date descending (Newest at the top)
# - Drop duplicates of the license_number, keeping only the first (the newest)
final_upgrades_df = (
    matched_df
    .sort_values(by='minutes_date', ascending=False)
    .drop_duplicates(subset='license_number', keep='first')
)

# 5. Calculate Metrics for Reporting
found_count = len(final_upgrades_df)
total_requested = len(UPGRADES)
found_ids = set(final_upgrades_df['license_number'].unique())
missed_ids = [uid for uid in UPGRADES if uid not in found_ids]

# 6. Print Summary Report
print("-" * 30)
print(f"UPGRADE MATCHING REPORT")
print("-" * 30)
print(f"Total IDs requested: {total_requested}")
print(f"Unique matches found: {found_count}")

if missed_ids:
    print(f"\n❌ Missed IDs ({len(missed_ids)}):")
    for mid in missed_ids:
        print(f" - {mid}")
else:
    print("\n✅ All IDs successfully matched!")

print("-" * 30)

# 7. Display the result (newest first)
# Selecting specific columns for a cleaner view in the notebook
view_cols = ['license_number', 'minutes_date', 'business_name', 'dba_name']
# Only show columns that actually exist in your dataframe
existing_cols = [c for c in view_cols if c in final_upgrades_df.columns]

final_upgrades_df[existing_cols].sort_values(by='minutes_date', ascending=False)
# Out:
# ------------------------------
# UPGRADE MATCHING REPORT
# ------------------------------
# Total IDs requested: 5
# Unique matches found: 5
#
# ✅ All IDs successfully matched!
# ------------------------------
#    license_number minutes_date                business_name  \
# 2        LB-99607   2026-01-28         Bop Productions, LLC
# 10       LB-99779   2026-01-28          Nite Lite Cafe, LLC
# 13       LB-99753   2026-01-28               Schiaffo, Inc.
# 15       LB-99619   2026-01-28  SMG Newbury Restaurant, LLC
# 18       LB-99709   2026-01-28               Wichcraft, LLC
#
#                             dba_name
# 2                              Bebop
# 10                        89 Charles
# 13                        Carmelinas
# 15                          Serafina
# 18  New England Wicked Craft Company
