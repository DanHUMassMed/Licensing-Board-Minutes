# %%
import pandas as pd

licenses_df = pd.read_excel("../licenses.xlsx")
licenses_df.head()
# Out:
#   minutes_date license_number           business_name              dba_name  \
# 0   2026-01-28       LB-99286            Alasty Corp.         Napper Tandys
# 1   2026-01-28      LB-100327          AYA Pizza, LLC        Red Line Pizza
# 2   2026-01-28       LB-99607    Bop Productions, LLC                 Bebop
# 3   2026-01-28      LB-454368         BPM Events, LLC  Boston Public Market
# 4   2026-01-28       LB-99164  Eddie Vs Holdings, LLC              Eddie Vs
#
#                                           address street_number  \
# 0   4187-4195 Washington St, Roslindale, MA 02131     4187-4195
# 1  580-582 Dorchester Ave, South Boston, MA 02127       580-582
# 2              1116 Boylston St, Boston, MA 02115          1116
# 3                100 Hanover St, Boston, MA 02108           100
# 4               800 Boylston St, Boston, MA 02199           800
#
#       street_name          city state  zipcode             alcohol_type  \
# 0   Washington St    Roslindale    MA   2131.0  all alcoholic beverages
# 1  Dorchester Ave  South Boston    MA   2127.0  all alcoholic beverages
# 2     Boylston St        Boston    MA   2115.0  all alcoholic beverages
# 3      Hanover St        Boston    MA   2108.0  all alcoholic beverages
# 4     Boylston St        Boston    MA   2199.0  all alcoholic beverages
#
#              manager          attorney     status  \
# 0           Callejas     Mark A. White  continued
# 1                NaN               NaN    granted
# 2                NaN               NaN    granted
# 3                NaN  Dennis A. Quilty    granted
# 4  Eric Edward Gurry  Dennis A. Quilty   deferred
#
#                                        status_detail  \
# 0  Continued to the February 11 Transactional Hea...
# 1  Granted, for delivery only between 11:00 PM an...
# 2                                            Granted
# 3                                            Granted
# 4  application deadline. Deliberation on these ap...
#
#                                              details  entity_number  \
# 0  Holder of a Common Victualler 7 Day All-Alcoho...             15
# 1  Holder of a Common Victualler License has peti...              2
# 2  Holder of a Common Victualler 7 Day Wines and ...             12
# 3  Holder of a Common Victualler 7 Day All-Alcoho...              5
# 4  Holder of a Common Victualler 7 Day All-Alcoho...             17
#
#                        file_name
# 0  voting_minutes_2026-01-29.pdf
# 1  voting_minutes_2026-01-29.pdf
# 2  voting_minutes_2026-01-29.pdf
# 3  voting_minutes_2026-01-29.pdf
# 4  voting_minutes_2026-01-29.pdf

# %%
applying_bus=["Crystal Spoons, LLC", "El Centro", "La Parada Dominican Kitchen", "Murl's Kitchen", "JustBook-ish", 
"Minina Cafe", "One Family Diner", "Fresh Food Generation", "Blue Mountain Jamaican Restaurant", "Angelas Cafe", 
"Cabana Grill", "Caffe Dello Sport Eastie", "Con Sabor A Colombia, Inc.", "Florenza", "Mi Pueblito Restaurant", 
"Peruvian Taste Restaurant", "BB.Q Chicken", "Don Tequeno y Dona Arepa", "Mangu Dominican Bistro", "Momo Masala", 
"Stoked Pizza", "Harry's All American", "Mi Finca Mexican Restaurant and Pizzeria", "Las Delicias Colombianas 2", "Little Haiti International Cuisine", "Huntington Theatre", 
"Jeffries Yacht Club", "Zoo New England", "SubRosa and Humaari", "El Barrio Mexican Grill", "Mesob Restaurant", "Mondo", 
"Wash El Beverages, LLC", "District 7 Cafe", "The Mix Vault", "The Weston Way, LLC", "Cool Shade Jamaican Restaurant, LLC", "Blasi Cafe", 
"Milkweed", "Pizza 24", "Doune & Pepe", "Molinaris", "Chilacates Cantina", "Mofongo Factory Restaurant", "El Jardin", 
"Los Alebrijes Restaurant", "Taqueria Jalisco", "The Smoke Shop BBQ", "La Tavernetta by Mida", "AAA Restaurant", "Jadu", 
"Miami Restaurant", "Mr Drinky", "The Green T Coffee Shop", "Knoll Street Tavern", "sweeties", "Somtum Modern Thai Cuisine", 
"Boston Pickle Club", "Capri", "Bono Restaurant and Catering", "American Repertory Theatre", "Boston Center for the Arts", 
"Sorrel and Lime, LLC", "The Substation", "From Scratch", "Mos Tavern & Kitchen", "AMA", 
"Gracenote Coffee Boston", "Merengue Express"]

# %%
import pandas as pd

# 1. Standardize the lookup set
applying_bus_set = set(name.strip().lower() for name in applying_bus)

# 2. Check for required columns
cols = licenses_df.columns
if "business_name" in cols and "dba_name" in cols:
    
    # 3. Create boolean masks for both columns
    # We strip and lower both for a fair comparison
    mask_bus = licenses_df["business_name"].str.strip().str.lower().isin(applying_bus_set)
    mask_dba = licenses_df["dba_name"].str.strip().str.lower().isin(applying_bus_set)
    
    # 4. Filter DF where either column matches (| is the OR operator)
    matched_df = licenses_df[mask_bus | mask_dba].copy()
    
    # 5. Calculate missed businesses
    # Collect all names found in either column of our results
    found_bus_names = set(matched_df["business_name"].str.strip().str.lower())
    found_dba_names = set(matched_df["dba_name"].str.strip().str.lower())
    all_found_names = found_bus_names.union(found_dba_names)
    
    missed_names = [name for name in applying_bus if name.strip().lower() not in all_found_names]
    
    # 6. Print Results
    print(f"Found {len(matched_df)} matching rows.")
    print(f"Unique businesses matched: {len(applying_bus) - len(missed_names)} out of {len(applying_bus)}")
    
    if missed_names:
        print(f"\nMissed Businesses ({len(missed_names)}):")
        for name in missed_names:
            print(f" - {name}")
            
    # Display the result
    display(matched_df) # Use display() in notebooks for better formatting
    
else:
    missing = [c for c in ["business_name", "dba_name"] if c not in licenses_df.columns]
    print(f"Error: Missing columns in licenses_df: {missing}")
# Out:
# Found 98 matching rows.
# Unique businesses matched: 69 out of 69
#      minutes_date license_number                             business_name  \
# 118    2025-10-01      LB-607770                La Tavernetta by Mida, LLC
# 217    2025-07-29      LB-601427                         El Barrio MX, LLC
# 220    2025-07-29      LB-601428                             J.J. & R, LLC
# 228    2025-07-29      LB-601426                           Shunny Day, LLC
# 231    2025-07-16      LB-599561  American Repertory Theatre Company, Inc.
# ...           ...            ...                                       ...
# 1942   2021-07-28      LB-456206                                Gelas Corp
# 2191   2021-01-26      LB-465577                                Gelas Corp
# 2225   2020-12-23      LB-440974                        Walter Corporation
# 2261   2020-10-28       LB-99639                         ALLSTON BBQ, LLC.
# 2270   2020-10-28      LB-144189                         DLS Kitchen, Inc.
#
#                         dba_name  \
# 118        La Tavernetta by Mida
# 217      El Barrio Mexican Grill
# 220                The Mix Vault
# 228                        mondo
# 231   American Repertory Theatre
# ...                          ...
# 1942  Las Delicias Colombianas 2
# 2191  Las Delicias Colombianas 2
# 2225                   El Jardin
# 2261                BB.Q Chicken
# 2270      Mangu Dominican Bistro
#
#                                              address street_number  \
# 118            35-45 Lewis St, East Boston, MA 02128         35-45
# 217           809-811 Harrison Ave, Boston, MA 02118       809-811
# 220          720A-720 Shawmut Ave, Roxbury, MA 02119      720A-720
# 228               563 Columbus Ave, Boston, MA 02118           563
# 231             175 N. Harvard St, Allston, MA 02134           175
# ...                                              ...           ...
# 1942             1231 River St., Hyde Park, MA 02136          1231
# 2191             1231 River St., Hyde Park, MA 02136          1231
# 2225  15  WILLIAM C KELLY SQ, EAST BOSTON, MA  02128            15
# 2261             182  HARVARD AVE, BOSTON, MA  02134           182
# 2270    264  HYDE PARK AVE, JAMAICA PLAIN, MA  02130           264
#
#              street_name           city state  zipcode  \
# 118             Lewis St    East Boston    MA   2128.0
# 217         Harrison Ave         Boston    MA   2118.0
# 220          Shawmut Ave        Roxbury    MA   2119.0
# 228         Columbus Ave         Boston    MA   2118.0
# 231        N. Harvard St        Allston    MA   2134.0
# ...                  ...            ...   ...      ...
# 1942            River St      Hyde Park    MA   2136.0
# 2191            River St      Hyde Park    MA   2136.0
# 2225  William C Kelly Sq    East Boston    MA   2128.0
# 2261         Harvard Ave         Boston    MA   2134.0
# 2270       Hyde Park Ave  Jamaica Plain    MA   2130.0
#
#                  alcohol_type                       manager  \
# 118   all alcoholic beverages             Douglass Williams
# 217   all alcoholic beverages                     Joandry J
# 220   all alcoholic beverages                 Rufus J Faulk
# 228   all alcoholic beverages                 Spenser Payne
# 231   all alcoholic beverages                 Anna Fitzloff
# ...                       ...                           ...
# 1942  all alcoholic beverages                        Miguel
# 2191  all alcoholic beverages          Miguel Angel Gallego
# 2225  all alcoholic beverages  John Walter Castaneda Garcia
# 2261  all alcoholic beverages              Tarek Ali Hassan
# 2270  all alcoholic beverages                           NaN
#
#                 attorney    status  \
# 118     Elizabeth Pisano   granted
# 217                  NaN  deferred
# 220                  NaN  deferred
# 228   Kristen L. Scanlon  deferred
# 231     Dennis A. Quilty  deferred
# ...                  ...       ...
# 1942                 NaN   granted
# 2191                 NaN   granted
# 2225                 NaN   granted
# 2261   Stephen V. Miller   granted
# 2270                 NaN   granted
#
#                                           status_detail  \
# 118   Granted a ZIP Code Restricted All Alcoholic Be...
# 217                                            Deferred
# 220                                            Deferred
# 228                                            Deferred
# 231                                            Deferred
# ...                                                 ...
# 1942          Granted pending availability of a license
# 2191  Granted, pending the availability of a license...
# 2225                                            GRANTED
# 2261                                           Granted.
# 2270  Granted - takeout and delivery only from 9:00p...
#
#                                                 details  entity_number  \
# 118   Has applied for a Common Victualler 7 Day All-...             18
# 217   Has applied for a Common Victualler 7 Day All-...             12
# 220   Has applied for a Common Victualler 7 Day All-...             13
# 228   Has applied for a Common Victualler 7 Day All-...             11
# 231   Has applied for a Common Victualler 7 Day All-...             15
# ...                                                 ...            ...
# 1942  Has applied for a Common Victualler 7 Day Wine...             26
# 2191  Has applied for a Common Victualler 7 Day Wine...             27
# 2225  Has applied for a Common Victualler License to...              2
# 2261  Holder of a Common Victualler 7 Day Wines and ...             22
# 2270  Holder of a Common Victualler License has peti...              3
#
#                           file_name
# 118   voting_minutes_2025-10-01.pdf
# 217   voting_minutes_2025-07-31.pdf
# 220   voting_minutes_2025-07-31.pdf
# 228   voting_minutes_2025-07-31.pdf
# 231   voting_minutes_2025-07-17.pdf
# ...                             ...
# 1942  voting_minutes_2021-07-29.pdf
# 2191  voting_minutes_2022-01-27.pdf
# 2225  voting_minutes_2020-12-23.pdf
# 2261  voting_minutes_2020-10-29.pdf
# 2270  voting_minutes_2020-10-29.pdf
#
# [98 rows x 18 columns]
